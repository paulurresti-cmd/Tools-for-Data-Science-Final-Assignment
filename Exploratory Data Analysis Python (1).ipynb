# %%
import pandas as pd
# Out:
# <ipython-input-1-7dd3504c366f>:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
import numpy s np
# Out:
#   Cell In[2], line 1
#     import numpy s np
#                  ^
# SyntaxError: invalid syntax

# %%
import numpyas np
# Out:
#   Cell In[3], line 1
#     import numpyas np
#                    ^
# SyntaxError: invalid syntax

# %%
import numpy as np

# %%
import piplite 
await piplite.install('seaborn')

# %%
from pyodide.http import pyfetch

async def download(url, filename):
    response = await pyfetch(url)
    if response.status == 200:
        with open(filename, "wb") as f:
            f.write(await response.bytes())

# %%
file_path= "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-SkillsNetwork/labs/Data%20files/automobileEDA.csv"

# %%
await download(file_path, "usedcars.csv")
file_name="usedcars.csv"

# %%
df=pd.read_csv(file_name)

# %%
df.head(5)
# Out:
#    symboling  normalized-losses         make aspiration num-of-doors  \
# 0          3                122  alfa-romero        std          two
# 1          3                122  alfa-romero        std          two
# 2          1                122  alfa-romero        std          two
# 3          2                164         audi        std         four
# 4          2                164         audi        std         four
#
#     body-style drive-wheels engine-location  wheel-base    length  ...  \
# 0  convertible          rwd           front        88.6  0.811148  ...
# 1  convertible          rwd           front        88.6  0.811148  ...
# 2    hatchback          rwd           front        94.5  0.822681  ...
# 3        sedan          fwd           front        99.8  0.848630  ...
# 4        sedan          4wd           front        99.4  0.848630  ...
#
#    compression-ratio  horsepower  peak-rpm city-mpg highway-mpg    price  \
# ...

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
# %matplotlib inline

# %%
#to know which graph is better

print(df.dtypes)
# Out:
# symboling              int64
# normalized-losses      int64
# make                  object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower           float64
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                float64
# city-L/100km         float64
# horsepower-binned     object
# diesel                 int64
# gas                    int64
# dtype: object

# %%
#what is peak-rpm type?

df['peak-rpm'].dtype
# Out:
# dtype('float64')

# %%
df['peak-rpm'].dtypes
# Out:
# dtype('float64')

# %%
numeric_df=df.select_dtypes(include=['float64','int64'])

# %%
numeric_df.corr()
# Out:
#                    symboling  normalized-losses  wheel-base    length  \
# symboling           1.000000           0.466264   -0.535987 -0.365404
# normalized-losses   0.466264           1.000000   -0.056661  0.019424
# wheel-base         -0.535987          -0.056661    1.000000  0.876024
# length             -0.365404           0.019424    0.876024  1.000000
# width              -0.242423           0.086802    0.814507  0.857170
# height             -0.550160          -0.373737    0.590742  0.492063
# curb-weight        -0.233118           0.099404    0.782097  0.880665
# engine-size        -0.110581           0.112360    0.572027  0.685025
# bore               -0.140019          -0.029862    0.493244  0.608971
# stroke             -0.008245           0.055563    0.158502  0.124139
# compression-ratio  -0.182196          -0.114713    0.250313  0.159733
# horsepower          0.075819           0.217299    0.371147  0.579821
# ...

# %%
df_bore_stroke_compratio_horsepower=df[['bore','stroke','compression-ratio','horsepower']]

# %%
df_bore_stroke_compratio_horsepower.corr()
# Out:
#                        bore    stroke  compression-ratio  horsepower
# bore               1.000000 -0.055390           0.001263    0.566936
# stroke            -0.055390  1.000000           0.187923    0.098462
# compression-ratio  0.001263  0.187923           1.000000   -0.214514
# horsepower         0.566936  0.098462          -0.214514    1.000000

# %%
#Scatterplot engine-size and price

plt.scatter('engine-size', 'price')

# %%
plt.scatter(['engine-size','price])
# Out:
#   Cell In[22], line 1
#     plt.scatter(['engine-size','price])
#                                ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
sns.regplot(x="engine-size",y="price", data=df)
plt.ylim(0,)
# Out:
# (0.0, 53561.89364188126)

# %%
plt.scatter(x='engine-size', y='price', data=df)

# %%
plt.scatter(x='engine-size', y='price', data=df)
plt.title("Scatterplot)
# Out:
#   Cell In[25], line 2
#     plt.title("Scatterplot)
#               ^
# SyntaxError: unterminated string literal (detected at line 2)

# %%
plt.scatter(x='engine-size', y='price', data=df)
plt.title("Scatterplot")
# Out:
# Text(0.5, 1.0, 'Scatterplot')

# %%
plt.scatter(x='engine-size', y='price', data=df)
plt.title("Scatterplot")
plt.xlabel("engine_size")
plt.ylabel("price")
# Out:
# Text(0, 0.5, 'price')

# %%
plt.scatter(x='engine-size', y='price')

# %%
plt.scatter(x='engine-size', y='price', data=df)

# %%
df[['engine-size','price']].corr()
# Out:
#              engine-size     price
# engine-size     1.000000  0.872335
# price           0.872335  1.000000

# %%
#Scatterplot highway-mpg and price

plt.scatter(x="highway-mpg", y="price", data=df)

# %%
sns.regplot(x="highway-mpg",y="price", data=df)
# Out:
# <AxesSubplot:xlabel='highway-mpg', ylabel='price'>

# %%
sns.regplot(x="highway-mpg",y="price", data=df)
plt.ylim(0,)
# Out:
# (0.0, 48147.485065517845)

# %%
df['highway-mpg','price'].corr()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /lib/python3.12/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File index.pyx:153, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:182, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('highway-mpg', 'price')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 df['highway-mpg','price'].corr()
#
# ...

# %%
df[['highway-mpg'],['price']].corr()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /lib/python3.12/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File index.pyx:153, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:159, in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(['highway-mpg'], ['price'])' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 df[['highway-mpg'],['price']].corr()
#
# File /lib/python3.12/site-packages/pandas/core/frame.py:4090, in DataFrame.__getitem__(self, key)
#    4088 if self.columns.nlevels > 1:
#    4089     return self._getitem_multilevel(key)
# ...

# %%
df['highway-mpg','price'].corr()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /lib/python3.12/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File index.pyx:153, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:182, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('highway-mpg', 'price')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 df['highway-mpg','price'].corr()
#
# ...

# %%
df[['highway-mpg','price']].corr()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df[['highway-mpg','price']].corr()
#
# NameError: name 'df' is not defined

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df.head()
#
# NameError: name 'df' is not defined

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import piplite
await piplite.install('seaborn')

# %%
from pyodide.http import pyfetch

async def download(url, filename):
    response = await pyfetch(url)
    if response.status == 200:
        with open(filename, "wb") as f:
            f.write(await response.bytes())

# %%
file_path= "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-SkillsNetwork/labs/Data%20files/automobileEDA.csv"

# %%
await download(file_path, "usedcars.csv")
file_name="usedcars.csv"

# %%
df=pd.read_csv(file_name, header=0)

# %%
df.head()
# Out:
#    symboling  normalized-losses         make aspiration num-of-doors  \
# 0          3                122  alfa-romero        std          two
# 1          3                122  alfa-romero        std          two
# 2          1                122  alfa-romero        std          two
# 3          2                164         audi        std         four
# 4          2                164         audi        std         four
#
#     body-style drive-wheels engine-location  wheel-base    length  ...  \
# 0  convertible          rwd           front        88.6  0.811148  ...
# 1  convertible          rwd           front        88.6  0.811148  ...
# 2    hatchback          rwd           front        94.5  0.822681  ...
# 3        sedan          fwd           front        99.8  0.848630  ...
# 4        sedan          4wd           front        99.4  0.848630  ...
#
#    compression-ratio  horsepower  peak-rpm city-mpg highway-mpg    price  \
# ...

# %%
import seaborn as sns
# %matplotlib inline

# %%
#data type peak-rpm

df[['peak-rpm']].dtype()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-6ca059aa04fd> in ?()
#       1 #data type peak-rpm
#       2
# ----> 3 df[['peak-rpm']].dtype()
#
# /lib/python3.12/site-packages/pandas/core/generic.py in ?(self, name)
#    6289             and name not in self._accessors
#    6290             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6291         ):
#    6292             return self[name]
# -> 6293         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'dtype'

# %%
df['peak-rpm'].dtype()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 df['peak-rpm'].dtype()
#
# TypeError: 'numpy.dtypes.Float64DType' object is not callable

# %%
df.dtypes()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 df.dtypes()
#
# TypeError: 'Series' object is not callable

# %%
df.head()
# Out:
#    symboling  normalized-losses         make aspiration num-of-doors  \
# 0          3                122  alfa-romero        std          two
# 1          3                122  alfa-romero        std          two
# 2          1                122  alfa-romero        std          two
# 3          2                164         audi        std         four
# 4          2                164         audi        std         four
#
#     body-style drive-wheels engine-location  wheel-base    length  ...  \
# 0  convertible          rwd           front        88.6  0.811148  ...
# 1  convertible          rwd           front        88.6  0.811148  ...
# 2    hatchback          rwd           front        94.5  0.822681  ...
# 3        sedan          fwd           front        99.8  0.848630  ...
# 4        sedan          4wd           front        99.4  0.848630  ...
#
#    compression-ratio  horsepower  peak-rpm city-mpg highway-mpg    price  \
# ...

# %%
df.dtypes()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 df.dtypes()
#
# TypeError: 'Series' object is not callable

# %%
df.dtypes
# Out:
# symboling              int64
# normalized-losses      int64
# make                  object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower           float64
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                float64
# city-L/100km         float64
# horsepower-binned     object
# diesel                 int64
# gas                    int64
# dtype: object

# %%
df['peak-rpm'].dtype
# Out:
# dtype('float64')

# %%
df.dtypes(include=['float64','int64']).corr()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 df.dtypes(include=['float64','int64']).corr()
#
# TypeError: 'Series' object is not callable

# %%
df.dtype(include=['float64','int64']).corr()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-1d7109217e2d> in ?()
# ----> 1 df.dtype(include=['float64','int64']).corr()
#
# /lib/python3.12/site-packages/pandas/core/generic.py in ?(self, name)
#    6289             and name not in self._accessors
#    6290             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6291         ):
#    6292             return self[name]
# -> 6293         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'dtype'

# %%
df.dtype(include=[['float64','int64']]).corr()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-a47ba08325cf> in ?()
# ----> 1 df.dtype(include=[['float64','int64']]).corr()
#
# /lib/python3.12/site-packages/pandas/core/generic.py in ?(self, name)
#    6289             and name not in self._accessors
#    6290             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6291         ):
#    6292             return self[name]
# -> 6293         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'dtype'

# %%
numeric_df=df.select_dtypes(include['float64','int64'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 numeric_df=df.select_dtypes(include['float64','int64'])
#
# NameError: name 'include' is not defined

# %%
numeric_df=df.select_dtypes(include=['float64','int64'])

# %%
numeric_df.corr()
# Out:
#                    symboling  normalized-losses  wheel-base    length  \
# symboling           1.000000           0.466264   -0.535987 -0.365404
# normalized-losses   0.466264           1.000000   -0.056661  0.019424
# wheel-base         -0.535987          -0.056661    1.000000  0.876024
# length             -0.365404           0.019424    0.876024  1.000000
# width              -0.242423           0.086802    0.814507  0.857170
# height             -0.550160          -0.373737    0.590742  0.492063
# curb-weight        -0.233118           0.099404    0.782097  0.880665
# engine-size        -0.110581           0.112360    0.572027  0.685025
# bore               -0.140019          -0.029862    0.493244  0.608971
# stroke             -0.008245           0.055563    0.158502  0.124139
# compression-ratio  -0.182196          -0.114713    0.250313  0.159733
# horsepower          0.075819           0.217299    0.371147  0.579821
# ...

# %%
#corr bore, stroke, compression-ratio, horsepower

df[['bore','stroke','compression-ratio','horsepower']].corr()
# Out:
#                        bore    stroke  compression-ratio  horsepower
# bore               1.000000 -0.055390           0.001263    0.566936
# stroke            -0.055390  1.000000           0.187923    0.098462
# compression-ratio  0.001263  0.187923           1.000000   -0.214514
# horsepower         0.566936  0.098462          -0.214514    1.000000

# %%
#scatterplot between engine-size and price:

df[['engine-size','price']].sns.regplot(x='engine-size', y='price', data=df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-329e874aeda3> in ?()
#       1 #scatterplot between engine-size and price:
#       2
# ----> 3 df[['engine-size','price']].sns.regplot(x='engine-size', y='price', data=df)
#
# /lib/python3.12/site-packages/pandas/core/generic.py in ?(self, name)
#    6289             and name not in self._accessors
#    6290             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6291         ):
#    6292             return self[name]
# -> 6293         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'sns'

# %%
df.sns.regplot(x='engine-size', y='price', data=df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-34-10c59e68e1d6> in ?()
# ----> 1 df.sns.regplot(x='engine-size', y='price', data=df)
#
# /lib/python3.12/site-packages/pandas/core/generic.py in ?(self, name)
#    6289             and name not in self._accessors
#    6290             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6291         ):
#    6292             return self[name]
# -> 6293         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'sns'

# %%
sns.regplot(x='engine-size', y='price', data=df)
# Out:
# <AxesSubplot:xlabel='engine-size', ylabel='price'>

# %%
sns.regplot(x='engine-size', y='price', data=df)
plt.ylim(0,)
# Out:
# (0.0, 53399.84731496265)

# %%
df[['engine-size','price']].corr()
# Out:
#              engine-size     price
# engine-size     1.000000  0.872335
# price           0.872335  1.000000

# %%
#scatterplot highway-mpg and price

sns regplot(x='highway-mpg', y='price', data=df)
# Out:
#   Cell In[38], line 3
#     sns regplot(x='highway-mpg', y='price', data=df)
#         ^
# SyntaxError: invalid syntax

# %%
sns.regplot(x='highway-mpg',y='price', data=df)
# Out:
# <AxesSubplot:xlabel='highway-mpg', ylabel='price'>

# %%
df[['highway-mpg','price']].corr()
# Out:
#              highway-mpg     price
# highway-mpg     1.000000 -0.704692
# price          -0.704692  1.000000

# %%
sns.regplot(x='peak-rpm', y='price', data=df)
# Out:
# <AxesSubplot:xlabel='peak-rpm', ylabel='price'>

# %%
df[['peak-rpm','price']].corr()
# Out:
#           peak-rpm     price
# peak-rpm  1.000000 -0.101616
# price    -0.101616  1.000000

# %%
#corr stroke and price 

df[['stroke','price']].corr()
# Out:
#          stroke    price
# stroke  1.00000  0.08231
# price   0.08231  1.00000

# %%
sns.regplot(x='stroke', y='price', data=df)
# Out:
# <AxesSubplot:xlabel='stroke', ylabel='price'>

# %%
#boxplot for categorical variables

sns.boxplot(x='body-style')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[45], line 3
#       1 #boxplot for categorical variables
# ----> 3 sns.boxplot(x='body-style')
#
# File /lib/python3.12/site-packages/seaborn/categorical.py:1597, in boxplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, dodge, width, gap, whis, linecolor, linewidth, fliersize, hue_norm, native_scale, log_scale, formatter, legend, ax, **kwargs)
#    1589 def boxplot(
#    1590     data=None, *, x=None, y=None, hue=None, order=None, hue_order=None,
#    1591     orient=None, color=None, palette=None, saturation=.75, fill=True,
#    (...)
#    1594     legend="auto", ax=None, **kwargs
#    1595 ):
# -> 1597     p = _CategoricalPlotter(
#    1598         data=data,
#    1599         variables=dict(x=x, y=y, hue=hue),
#    1600         order=order,
#    1601         orient=orient,
# ...

# %%
sns.boxplot(x='body-style', y='price', data=df)
# Out:
# <AxesSubplot:xlabel='body-style', ylabel='price'>

# %%
sns.boxplot(x='engine location', y='price', data=df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 sns.boxplot(x='engine location', y='price', data=df)
#
# File /lib/python3.12/site-packages/seaborn/categorical.py:1597, in boxplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, dodge, width, gap, whis, linecolor, linewidth, fliersize, hue_norm, native_scale, log_scale, formatter, legend, ax, **kwargs)
#    1589 def boxplot(
#    1590     data=None, *, x=None, y=None, hue=None, order=None, hue_order=None,
#    1591     orient=None, color=None, palette=None, saturation=.75, fill=True,
#    (...)
#    1594     legend="auto", ax=None, **kwargs
#    1595 ):
# -> 1597     p = _CategoricalPlotter(
#    1598         data=data,
#    1599         variables=dict(x=x, y=y, hue=hue),
#    1600         order=order,
#    1601         orient=orient,
#    1602         color=color,
# ...

# %%
sns.boxplot(x='engine-location', y='price', data=df)
# Out:
# <AxesSubplot:xlabel='engine-location', ylabel='price'>

# %%
sns.boxplot(x='drive-wheels', y='price', data=df)
# Out:
# <AxesSubplot:xlabel='drive-wheels', ylabel='price'>

# %%
#descriptive statistical analysis

df.describe()
# Out:
#         symboling  normalized-losses  wheel-base      length       width  \
# count  201.000000          201.00000  201.000000  201.000000  201.000000
# mean     0.840796          122.00000   98.797015    0.837102    0.915126
# std      1.254802           31.99625    6.066366    0.059213    0.029187
# min     -2.000000           65.00000   86.600000    0.678039    0.837500
# 25%      0.000000          101.00000   94.500000    0.801538    0.890278
# 50%      1.000000          122.00000   97.000000    0.832292    0.909722
# 75%      2.000000          137.00000  102.400000    0.881788    0.925000
# max      3.000000          256.00000  120.900000    1.000000    1.000000
#
#            height  curb-weight  engine-size        bore      stroke  \
# count  201.000000   201.000000   201.000000  201.000000  197.000000
# mean    53.766667  2555.666667   126.875622    3.330692    3.256904
# std      2.447822   517.296727    41.546834    0.268072    0.319256
# ...

# %%
df.describe(include{'float64'})
# Out:
#   Cell In[51], line 1
#     df.describe(include{'float64'})
#                 ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
df.describe(include={'float64'})
# Out:
#        wheel-base      length       width      height        bore      stroke  \
# count  201.000000  201.000000  201.000000  201.000000  201.000000  197.000000
# mean    98.797015    0.837102    0.915126   53.766667    3.330692    3.256904
# std      6.066366    0.059213    0.029187    2.447822    0.268072    0.319256
# min     86.600000    0.678039    0.837500   47.800000    2.540000    2.070000
# 25%     94.500000    0.801538    0.890278   52.000000    3.150000    3.110000
# 50%     97.000000    0.832292    0.909722   54.100000    3.310000    3.290000
# 75%    102.400000    0.881788    0.925000   55.500000    3.580000    3.410000
# max    120.900000    1.000000    1.000000   59.800000    3.940000    4.170000
#
#        compression-ratio  horsepower     peak-rpm         price  city-L/100km
# count         201.000000  201.000000   201.000000    201.000000    201.000000
# mean           10.164279  103.405534  5117.665368  13207.129353      9.944145
# ...

# %%
#value counts

df['drive-wheels'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0      rwd
# 1      rwd
# 2      rwd
# 3      fwd
# 4      4wd
#       ...
# 196    rwd
# 197    rwd
# 198    rwd
# 199    rwd
# 200    rwd
# Name: drive-wheels, Length: 201, dtype: object>

# %%
df['drive-wheels'].value_counts()
# Out:
# drive-wheels
# fwd    118
# rwd     75
# 4wd      8
# Name: count, dtype: int64

# %%
#convert to frame

df['drive-wheels'].value_counts().toframe()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-55-6c5aa7383805> in ?()
#       1 #convert to frame
#       2
# ----> 3 df['drive-wheels'].value_counts().toframe()
#
# /lib/python3.12/site-packages/pandas/core/generic.py in ?(self, name)
#    6289             and name not in self._accessors
#    6290             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6291         ):
#    6292             return self[name]
# -> 6293         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'toframe'

# %%
df['drive-wheels'].value_counts.toframe()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 df['drive-wheels'].value_counts.toframe()
#
# AttributeError: 'function' object has no attribute 'toframe'

# %%
df['drive-wheels'].value_counts.to_frame()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 df['drive-wheels'].value_counts.to_frame()
#
# AttributeError: 'function' object has no attribute 'to_frame'

# %%
df['drive-wheels'].value_counts().to_frame()
# Out:
#               count
# drive-wheels
# fwd             118
# rwd              75
# 4wd               8

# %%
df_drive_wheels=df.value_counts().to_frame

# %%
df_drive_wheels=df.value_counts().to_frame()

# %%
df_drive_wheels.rename(columns={'drive-wheels':'value_counts'})
# Out:
#                                                                                                                                                                                                                                                                                                                                          count
# symboling normalized-losses make          aspiration num-of-doors body-style drive-wheels engine-location wheel-base length   width    height curb-weight engine-type num-of-cylinders engine-size fuel-system bore stroke compression-ratio horsepower peak-rpm city-mpg highway-mpg price   city-L/100km horsepower-binned diesel gas
# ...

# %%
df_drive_wheels_count=df['drive_wheels'].value_counts().to_frame()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /lib/python3.12/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File index.pyx:153, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:182, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'drive_wheels'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 df_drive_wheels_count=df['drive_wheels'].value_counts().to_frame()
#
# ...

# %%
df.head()
# Out:
#    symboling  normalized-losses         make aspiration num-of-doors  \
# 0          3                122  alfa-romero        std          two
# 1          3                122  alfa-romero        std          two
# 2          1                122  alfa-romero        std          two
# 3          2                164         audi        std         four
# 4          2                164         audi        std         four
#
#     body-style drive-wheels engine-location  wheel-base    length  ...  \
# 0  convertible          rwd           front        88.6  0.811148  ...
# 1  convertible          rwd           front        88.6  0.811148  ...
# 2    hatchback          rwd           front        94.5  0.822681  ...
# 3        sedan          fwd           front        99.8  0.848630  ...
# 4        sedan          4wd           front        99.4  0.848630  ...
#
#    compression-ratio  horsepower  peak-rpm city-mpg highway-mpg    price  \
# ...

# %%
df_drive_wheels_count=df[['drive_wheels']].value_counts().to_frame()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 df_drive_wheels_count=df[['drive_wheels']].value_counts().to_frame()
#
# File /lib/python3.12/site-packages/pandas/core/frame.py:4096, in DataFrame.__getitem__(self, key)
#    4094     if is_iterator(key):
#    4095         key = list(key)
# -> 4096     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4098 # take() does not accept boolean indexers
#    4099 if getattr(indexer, "dtype", None) == bool:
#
# File /lib/python3.12/site-packages/pandas/core/indexes/base.py:6199, in Index._get_indexer_strict(self, key, axis_name)
#    6196 else:
#    6197     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6199 self._raise_if_missing(keyarr, indexer, axis_name)
#    6201 keyarr = self.take(indexer)
#    6202 if isinstance(key, Index):
# ...

# %%
df_drive_wheels_count=df[['drive-wheels']].value_counts().to_frame()

# %%
df_drive_wheels_count.head(5)
# Out:
#               count
# drive-wheels
# fwd             118
# rwd              75
# 4wd               8

# %%
df_drive_wheels_count.reset_index(inplace=True)

# %%
drive_wheels_count.rename(columns={'drive-wheels','value_counts'})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 drive_wheels_count.rename(columns={'drive-wheels','value_counts'})
#
# NameError: name 'drive_wheels_count' is not defined

# %%
df_drive_wheels_count.rename(columns={'drive-wheels':'value_counts'}, inplace=True)

# %%
df_drive_wheels_count
# Out:
#   value_counts  count
# 0          fwd    118
# 1          rwd     75
# 2          4wd      8

# %%
df_drive_wheels_count.index.name='drive-wheels'

# %%
df_drive_wheels_count
# Out:
#              value_counts  count
# drive-wheels
# 0                     fwd    118
# 1                     rwd     75
# 2                     4wd      8
